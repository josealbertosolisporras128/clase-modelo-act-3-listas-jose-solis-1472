# %% [markdown]
# <a href="https://colab.research.google.com/github/josealbertosolisporras128/clase-modelo-act-3-listas-jose-solis-1472/blob/main/UIII_Act_3_listas_con_funciones_jose_1472.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### jose solis NL 51 fecha 11 mayo 2026
# #### Listas de modelo

# %%
# =========================
# MENÚ DE LISTAS
# =========================

lista = []

# =========================
# Agregar
# =========================
def agregarProducto():
    nombre = input("Ingrese nombre del producto: ")
    precio = float(input("Ingrese precio: "))

    producto = {
        "nombre": nombre,
        "precio": precio
    }

    lista.append(producto)
    print("Producto agregado correctamente.\n")


# =========================
# Leer
# =========================
def leerProducto():

    if len(lista) == 0:
        print("No hay productos registrados.\n")
        return

    posicion = int(input("Ingrese posición del producto: "))

    if 0 <= posicion < len(lista):
        print(lista[posicion])
    else:
        print("Posición inválida.\n")


# =========================
# Listar
# =========================
def listarProductos():

    if len(lista) == 0:
        print("Lista vacía.\n")
        return

    print("\n===== LISTA DE PRODUCTOS =====")

    for i, producto in enumerate(lista):
        print(f"{i} -> Nombre: {producto['nombre']} | Precio: {producto['precio']}")

    print()


# =========================
# Buscar
# =========================
def buscarProducto():

    nombre = input("Ingrese nombre a buscar: ")

    encontrado = False

    for producto in lista:

        if producto["nombre"].lower() == nombre.lower():
            print("Producto encontrado:")
            print(producto)
            encontrado = True

    if not encontrado:
        print("Producto no encontrado.\n")


# =========================
# Modificar
# =========================
def modificarProducto():

    nombre = input("Ingrese nombre del producto a modificar: ")

    for producto in lista:

        if producto["nombre"].lower() == nombre.lower():

            nuevoNombre = input("Nuevo nombre: ")
            nuevoPrecio = float(input("Nuevo precio: "))

            producto["nombre"] = nuevoNombre
            producto["precio"] = nuevoPrecio

            print("Producto modificado correctamente.\n")
            return

    print("Producto no encontrado.\n")


# =========================
# Borrar
# =========================
def borrarProducto():

    nombre = input("Ingrese nombre del producto a borrar: ")

    for producto in lista:

        if producto["nombre"].lower() == nombre.lower():

            lista.remove(producto)

            print("Producto eliminado correctamente.\n")
            return

    print("Producto no encontrado.\n")


# =========================
# MENÚ PRINCIPAL
# =========================

while True:

    print("===== MENÚ =====")
    print("1. Agregar producto")
    print("2. Leer producto")
    print("3. Listar productos")
    print("4. Buscar producto")
    print("5. Modificar producto")
    print("6. Borrar producto")
    print("7. Salir")

    opcion = input("Seleccione una opción: ")

    if opcion == "1":
        agregarProducto()

    elif opcion == "2":
        leerProducto()

    elif opcion == "3":
        listarProductos()

    elif opcion == "4":
        buscarProducto()

    elif opcion == "5":
        modificarProducto()

    elif opcion == "6":
        borrarProducto()

    elif opcion == "7":
        print("Saliendo del programa...")
        break

    else:
        print("Opción inválida.\n")
# Out:
# ===== MENÚ =====
# 1. Agregar producto
# 2. Leer producto
# 3. Listar productos
# 4. Buscar producto
# 5. Modificar producto
# 6. Borrar producto
# 7. Salir
# Seleccione una opción: 1
# Ingrese nombre del producto: pasarela
# Ingrese precio: 1000
# Producto agregado correctamente.
#
# ===== MENÚ =====
# 1. Agregar producto
# 2. Leer producto
# 3. Listar productos
# 4. Buscar producto
# 5. Modificar producto
# 6. Borrar producto
# 7. Salir
# Seleccione una opción: 1
# Ingrese nombre del producto: tacones
# Ingrese precio: 2000
# Producto agregado correctamente.
#
# ===== MENÚ =====
# 1. Agregar producto
# 2. Leer producto
# 3. Listar productos
# 4. Buscar producto
# 5. Modificar producto
# 6. Borrar producto
# 7. Salir
# Seleccione una opción: 1
# Ingrese nombre del producto: camara
# Ingrese precio: 600
# Producto agregado correctamente.
#
# ===== MENÚ =====
# 1. Agregar producto
# 2. Leer producto
# 3. Listar productos
# 4. Buscar producto
# 5. Modificar producto
# ...

# %% [markdown]
# ![texto del enlace](https://raw.githubusercontent.com/josealbertosolisporras128/clase-modelo-act-3-listas-jose-solis-1472/refs/heads/main/ChatGPT%20Image%2011%20may%202026%2C%2014_24_35.png)
